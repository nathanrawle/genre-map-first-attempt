# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from string import punctuation

import locale
locale.setlocale(locale.LC_ALL, '')
# Out:
# 'en_GB.UTF-8'

# %%
def series_setdiff(s1,s2):
    diff = np.setdiff1d(s1.dropna().unique(), s2.dropna().unique())
    print('Length:', len(diff))
    return diff

def series_intersect(s1,s2):
    intersection = np.intersect1d(s1.dropna().unique(), s2.dropna().unique())
    print('Length:', len(intersection))
    return intersection

def df_strip(df,keep_punc_only=True):
    
    df = df.copy()
    
    for col in df.columns:
        if df[ col ].dtype == 'O':
            if keep_punc_only:
                
                mask = ( df[ col ].str.fullmatch( '[' + punctuation + ']+' ) & df[ col ].notna() )
                only_punc = df.loc[ mask, col ]
                
                df[ col ] = df[ col ].str.strip( ' \t\r\n' + punctuation )
                
                df.update( only_punc )
                
            else:
                df[ col ] = df[ col ].str.strip( ' \t\r\n' + punctuation )
        else:
            continue
            
    return df

# %%
pd.set_option('display.max_rows', 100)
na_values = [
    '',
    '#N/A',
    '#N/A N/A',
    '#NA',
    '-1.#IND',
    '-1.#QNAN',
    '-NaN',
    '-nan',
    '1.#IND',
    '1.#QNAN',
    '<NA>',
    'N/A',
    'NULL',
    'NaN',
    'n/a',
    'nan',
    'null'
]

# %%
aliases_ = {
    
    'country': {
        'United States':'USA',
        'United States of America': 'USA',
        'US': 'USA',
        'U.S.': 'USA',
        'U.S.A.': 'USA',
        "People's Republic of China": "China",
        "Czech Republic": "Czechia",
        "Kingdom of the Netherlands": "The Netherlands",
        "Former Yugoslav Republic of Macedonia": "North Macedonia",
        "Macedonia": "North Macedonia",
        "F.Y.R.O.M.": "North Macedonia",
        "FYROM": "North Macedonia",
        "Socialist Federal Republic of Yugoslavia": "Yugoslavia",
        "Kingdom of Albania": "Albania",
        "Great Britain": "United Kingdom",
        "Sapin": "Spain",
        "Q13431386": "Australia"
    },
    
    'city': {
        'Washington, DC': 'Washington DC',
        'Washington, D.C.': 'Washington DC',
        'Ōsaka': 'Osaka'
    },
    
    'admin_area': {
        'Quebec City': 'Quebec',
        'Ōsaka': 'Osaka Prefecture',
        'Osaka': 'Osaka Prefecture',
    }
}

# %% [markdown]
# ## Countries

# %%
# countries = pd.read_csv('../warehouse/countryInfo.txt',
#                         sep='\t',
#                         skiprows=49,
#                         encoding='utf8',
#                         low_memory=False,
#                         na_values=na_values,
#                         keep_default_na=False)
# countries.to_csv('../warehouse/countryInfo.csv',index=False)

countries = pd.read_csv('../warehouse/countryInfo.csv',
                           encoding='utf8',
                           low_memory=False,
                           na_values=na_values,
                           keep_default_na=False)

# %%
countries['Country'] = countries['Country'].replace(aliases_['country'])

# %%
country_names = countries['Country'].values.tolist()

# %%
africa = countries.loc[countries['Continent']=='AF', 'Country'].values.tolist()
africa
# Out:
# ['Angola',
#  'Burkina Faso',
#  'Burundi',
#  'Benin',
#  'Botswana',
#  'Democratic Republic of the Congo',
#  'Central African Republic',
#  'Republic of the Congo',
#  'Ivory Coast',
#  'Cameroon',
#  'Cabo Verde',
#  'Djibouti',
#  'Algeria',
#  'Egypt',
#  'Western Sahara',
#  'Eritrea',
#  'Ethiopia',
#  'Gabon',
#  'Ghana',
#  'Gambia',
#  'Guinea',
#  'Equatorial Guinea',
#  'Guinea-Bissau',
#  'Kenya',
#  'Comoros',
#  'Liberia',
#  'Lesotho',
#  'Libya',
#  'Morocco',
#  'Madagascar',
#  'Mali',
#  'Mauritania',
#  'Mauritius',
#  'Malawi',
#  'Mozambique',
#  'Namibia',
#  'Niger',
#  'Nigeria',
#  'Reunion',
#  'Rwanda',
#  'Seychelles',
#  'Sudan',
#  'South Sudan',
#  'Saint Helena',
#  'Sierra Leone',
#  'Senegal',
#  'Somalia',
#  'Sao Tome and Principe',
#  'Eswatini',
#  'Chad',
#  'Togo',
#  'Tunisia',
#  'Tanzania',
#  'Uganda',
#  'Mayotte',
#  'South Africa',
#  'Zambia',
#  'Zimbabwe']

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ISO                 252 non-null    object
#  1   ISO3                252 non-null    object
#  2   ISO-Numeric         252 non-null    int64
#  3   fips                249 non-null    object
#  4   Country             252 non-null    object
#  5   Capital             246 non-null    object
#  6   Area(in sq km)      252 non-null    float64
#  7   Population          252 non-null    int64
#  8   Continent           252 non-null    object
#  9   tld                 251 non-null    object
#  10  CurrencyCode        251 non-null    object
#  11  CurrencyName        251 non-null    object
#  12  Phone               247 non-null    object
#  13  Postal Code Format  161 non-null    object
#  14  Postal Code Regex   161 non-null    object
#  15  Languages           249 non-null    object
#  16  geonameid           252 non-null    int64
#  17  neighbours          165 non-null    object
#  18  EquivalentFipsCode  1 non-null      object
# dtypes: float64(1), int64(3), object(15)
# memory usage: 37.5+ KB

# %% [markdown]
# ## Administrative areas

# %%
us_states = pd.read_html('https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States',
                         parse_dates=True)[0]

us_states.columns = [
    'state',
    'code',
    'capital',
    'largestCity',
    'ratified',
    'population',
    'areaTotal_mi2',
    'areaTotal_km2',
    'areaLand_mi2',
    'areaLand_km2',
    'areaWater_mi2',
    'areaWater_km2',
    'nRepresentatives'
]

# %%
us_state_names = us_states['state'].values.tolist()

# %%
us_counties = pd.read_html('https://en.wikipedia.org/wiki/List_of_United_States_counties_and_county_equivalents',
                          parse_dates=True)[3]

us_counties.columns = ['county','state','population','admin_name']

# %%
us_county_names = us_counties['county'].values.tolist()

# %%
uk_country_names = ['England','Northern Ireland','Scotland','Wales']

# %%
uk_counties = pd.read_html('https://en.wikipedia.org/wiki/List_of_counties_of_the_United_Kingdom',
                           parse_dates=True)

# %%
en_counties = uk_counties[0]

# %%
ni_counties = uk_counties[1]

# %%
sc_counties = uk_counties[2]

# %%
wa_counties = uk_counties[3]

# %%
en_counties['County','County'].str.strip('\s♠')
# Out:
# 0                              Avon
# 1      Bath and North East Somerset
# 2                      Bedfordshire
# 3                           Bedford
# 4                         Berkshire
#                    ...
# 107                       Yorkshire
# 108          Yorkshire, East Riding
# 109         Yorkshire, North Riding
# 110          Yorkshire, West Riding
# 111                            York
# Name: (County, County), Length: 112, dtype: object

# %%
uk_county_names = pd.concat([en_counties['County','County'],
                             ni_counties['County','County'],
                             sc_counties['County'],
                             wa_counties['County','County']],
                            ignore_index=True,
                            sort=True).str.strip('\s♠').values.tolist()

# %% [markdown]
# ## Cities
# - continent
# - country
# - countryCode
# - adminRegion
# - city:
#     - Plain-text
#     - Accented
# - lat
# - lon
# - pop.

# %% [markdown]
# ### cities from geonames
# http://download.geonames.org/export/dump/

# %%
fp = '../warehouse/cities500.txt'
usecols = [0,1,2,3,4,5,8,9,10,11,12,13,14,17,18]
col_names = {
    0:'id',
    1:'city',
    2:'city_ascii',
    3:'alternateNames',
    4:'lat',
    5:'lng',
    6:'featureClass',
    7:'featureCode',
    8:'iso2',
    9:'cc2',
    10:'admin1',
    11:'admin2',
    12:'admin3',
    13:'admin4',
    14:'population',
    15:'elevation',
    16:'elevationModel',
    17:'timezone',
    18:'modDate'
}

gn = pd.read_csv(fp,
                 sep='\t',
                 header=None,
                 usecols=usecols,
                 encoding='utf8',
                 low_memory=False,
                 na_values=na_values,
                 keep_default_na=False)

gn = gn.rename(columns=col_names).sort_values('population',ascending=False).drop_duplicates(['city','iso2'])

gn = gn.loc[gn['population'] > 0]

gn = pd.merge(gn,countries[['ISO','Country']].rename(columns={'ISO':'iso2','Country':'country'}),on='iso2',how='left')

gn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 147414 entries, 0 to 147413
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              147414 non-null  int64
#  1   city            147414 non-null  object
#  2   city_ascii      147397 non-null  object
#  3   alternateNames  118808 non-null  object
#  4   lat             147414 non-null  float64
#  5   lng             147414 non-null  float64
#  6   iso2            147414 non-null  object
#  7   cc2             5027 non-null    object
#  8   admin1          147384 non-null  object
#  9   admin2          128790 non-null  object
#  10  admin3          78581 non-null   object
#  11  admin4          30686 non-null   object
#  12  population      147414 non-null  int64
#  13  timezone        147414 non-null  object
#  14  modDate         147414 non-null  object
#  15  country         147414 non-null  object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 19.1+ MB

# %%
gn.loc[gn['population']==770].sort_values('country')
# Out:
#               id                                 city  \
# 117458   9972525                            Bangholme
# 117490   2142822                             Wuuluman
# 117428   2778340                 Göpfritz an der Wild
# 117484   2771841                               Maschl
# 117409   2762580                            Unterwald
# 117424    620959                              Tatarka
# 117474   2787830                                 Roly
# 117442   1805076                           Jiuxijiang
# 117447   1790151                         Xiaojiangkou
# 117433   8604562                       Velika Kosnica
# 117404   3070432                              Modlany
# 117444   3071714                              Líšnice
# 117467   3074788                             Hrubčice
# 117456   3023406                            Cottenchy
# 117469   2990443                                Nibas
# 117468   2991619                               Mosnes
# 117398   3008860                             Laguépie
# 117464   3032960                           Bettviller
# 117439   2989210                                  Ors
# 117460   2984294                                 Réau
# 117459   3032997                       Beton-Bazoches
# 117457   3017657                             Fosseuse
# 117453   2982205                             Ruffieux
# 117436   2981398                Saint-Benoît-du-Sault
# 117473   2991924                           Montverdun
# 117455   2983416                           Rivarennes
# 117479   2993248                           Monneville
# 117399   3001225                              Lesdins
# 117400   2996055                            Marcellaz
# 117492   2973039                   Teurthéville-Hague
# 117489   2972609                                Tigné
# 117406   3009194                        Lagarde-Enval
# 117483   2990298                                 Nocé
# 117419   3000332                          Les Mazures
# 117426    257411                     Méga Kefalóvryso
# 117415    734602                                Pigés
# 117402    736147                                Gríva
# 117410   6535481                             Rifreddo
# 117462   8949716                    Sant'Elena Irpina
# 117463   8949715                         Sant'Eulalia
# 117431   3219660                               Levego
# 117482   6535866                              Spadola
# 117412   2523313     Sant'Andrea Apostolo dello Ionio
# 117422   8722713                             Acatitla
# 117470   3980142                           Villamoros
# 117452   4024266                                Godoy
# 117418   4022669                        Puerto México
# 117449   8860869                          El Vainillo
# 117414   3523130                             Mitontic
# 117480   3821565                               Palula
# 117445   3530431                             Enríquez
# 117429   3483501                           Escoatitla
# 117430   8860871  Poblado Cinco (Nuevo Villa Ojitlán)
# 117465   8860870                           Los Mérida
# 117441   3999513                     Soledad de Abajo
# 117413   4013978                           Chupícuaro
# 117493   8860866                             Tamaloya
# 117488   2747585                               Schijf
# 117446   2759397                        Barsingerhorn
# 117411   2751669                              Leveroy
# 117438   2755801                           Froombosch
# 117432   2756636                            Dreischor
# 117403   3693764                       Pedregal Chico
# 117475    774158                            Ciepielów
# 117448    758567                             Sorkwity
# 117481   3095196                              Kórnica
# 117478   3082585                  Warta Bolesławiecka
# 117476   3087958                           Przelewice
# 117401    674048                            Mălăiești
# 117405    671760                         Orășeni-Vale
# 117471    679897                           Curtișoara
# 117451    669114                              Rătești
# 117461    675246                                 Jieț
# 117427    673974                               Maluri
# 117466   2125620                                Gatka
# 117437   2045765                         Devyatyy Val
# 117477   3189567                             Suhadole
# 117416   3117946                           Los Santos
# 117491   2509537                        Villapalacios
# 117421   2510686                                Tales
# 117417   2509833                  Valverde de Llerena
# 117440   2516685                             Holguera
# 117408    296578                                Yönlü
# 117443   4541773                            Lost City
# 117487   4055597                          Susan Moore
# 117485   4772042                           Maurertown
# 117494   4865545                               Lowden
# 117425    691841                             Zavoloka
# 117435   2648491                             Glenfarg
# 117486   2656020                              Beenham
# 117454   2650651                              Dunston
# 117407   2641675                         Newcastleton
# 117423   2656640                          Badwell Ash
# 117472   2645469                             Kingseat
# 117434   6324532                              Rigside
# 117450  10171181                             Stainton
# 117420   2639861                       Pulham St Mary
#
#                                  city_ascii  \
# 117458                            Bangholme
# 117490                             Wuuluman
# 117428                Goepfritz an der Wild
# 117484                               Maschl
# 117409                            Unterwald
# 117424                              Tatarka
# 117474                                 Roly
# 117442                           Jiuxijiang
# 117447                         Xiaojiangkou
# 117433                       Velika Kosnica
# 117404                              Modlany
# 117444                              Lisnice
# 117467                             Hrubcice
# 117456                            Cottenchy
# 117469                                Nibas
# 117468                               Mosnes
# 117398                             Laguepie
# 117464                           Bettviller
# 117439                                  Ors
# 117460                                 Reau
# 117459                       Beton-Bazoches
# 117457                             Fosseuse
# 117453                             Ruffieux
# 117436                Saint-Benoit-du-Sault
# 117473                           Montverdun
# 117455                           Rivarennes
# 117479                           Monneville
# 117399                              Lesdins
# 117400                            Marcellaz
# 117492                   Teurtheville-Hague
# 117489                                Tigne
# 117406                        Lagarde-Enval
# 117483                                 Noce
# 117419                          Les Mazures
# 117426                     Mega Kefalovryso
# 117415                                Piges
# 117402                                Griva
# 117410                             Rifreddo
# 117462                    Sant'Elena Irpina
# 117463                         Sant'Eulalia
# 117431                               Levego
# 117482                              Spadola
# 117412     Sant'Andrea Apostolo dello Ionio
# 117422                             Acatitla
# 117470                           Villamoros
# 117452                                Godoy
# 117418                        Puerto Mexico
# 117449                          El Vainillo
# 117414                             Mitontic
# 117480                               Palula
# 117445                             Enriquez
# 117429                           Escoatitla
# 117430  Poblado Cinco (Nuevo Villa Ojitlan)
# 117465                           Los Merida
# 117441                     Soledad de Abajo
# 117413                           Chupicuaro
# 117493                             Tamaloya
# 117488                               Schijf
# 117446                        Barsingerhorn
# 117411                              Leveroy
# 117438                           Froombosch
# 117432                            Dreischor
# 117403                       Pedregal Chico
# 117475                            Ciepielow
# 117448                             Sorkwity
# 117481                              Kornica
# 117478                  Warta Boleslawiecka
# 117476                           Przelewice
# 117401                            Malaiesti
# 117405                         Oraseni-Vale
# 117471                           Curtisoara
# 117451                              Ratesti
# 117461                                 Jiet
# 117427                               Maluri
# 117466                                Gatka
# 117437                         Devyatyy Val
# 117477                             Suhadole
# 117416                           Los Santos
# 117491                        Villapalacios
# 117421                                Tales
# 117417                  Valverde de Llerena
# 117440                             Holguera
# 117408                                Yonlu
# 117443                            Lost City
# 117487                          Susan Moore
# 117485                           Maurertown
# 117494                               Lowden
# 117425                             Zavoloka
# 117435                             Glenfarg
# 117486                              Beenham
# 117454                              Dunston
# 117407                         Newcastleton
# 117423                          Badwell Ash
# 117472                             Kingseat
# 117434                              Rigside
# 117450                             Stainton
# 117420                       Pulham St Mary
#
#                                            alternateNames       lat  \
# 117458                                                NaN -38.03842
# 117490                                                NaN -32.55000
# 117428  Gopfritz,Gopfritz an der Wild,Göpfritz,Göpfrit...  48.72497
# 117484                                                NaN  47.36667
# 117409                                                NaN  48.01667
# 117424                                    Tatarka,Татарка  53.25330
# 117474                               Philippeville (Roly)  50.13554
# 117442                         Chiu-hsi-chiang,Jiuxijiang  27.65556
# 117447   Hsiao-chiang-k'ou,Hsiao-chiang-k’ou,Xiaojiangkou  27.88028
# 117433                                                NaN  45.76094
# 117404                                             Modlan  50.65050
# 117444                                                NaN  50.07982
# 117467                                                NaN  49.45002
# 117456                                          Cottenchy  49.80954
# 117469                      Niba,Nibas,Nibo,ni ba,Ніба,尼巴  50.10232
# 117468                                                NaN  47.45589
# 117398                                  Laguepie,Laguépie  44.14426
# 117464  Bettviller,Bettweiler,Bettwiller,Betviler,bei ...  49.07927
# 117439                                 Or,Ors,ao er,Ор,奥尔  50.10056
# 117460                                          Reau,Réau  48.61022
# 117459                                     Beton-Bazoches  48.70076
# 117457                                           Fosseuse  49.21283
# 117453                                                NaN  45.84904
# 117436  Mont-du-Sault,Saint-Benoit,Saint-Benoit-du-Sau...  46.44036
# 117473                                         Montverdun  45.71937
# 117455                               Rivarenne,Rivarennes  47.26686
# 117479                                         Monneville  49.20708
# 117399                                            Lesdins  49.89732
# 117400  Marcellatium Fulciniensium,Marcellaz,Marcellaz...  46.14660
# 117492  Teurtheville,Teurtheville-Hague,Teurthéville-H...  49.58262
# 117489                  Tigne,Tigné,Tin'e,di nie,Тіньє,蒂涅  47.20033
# 117406                              Lagarde,Lagarde-Enval  45.18686
# 117483                                          Noce,Nocé  48.37908
# 117419                                        Les Mazures  49.88711
# 117426  Mega Kefalovrison,Mega Kefalovryso,Mega Kefalo...  39.58917
# 117415  Kutunjali,Kutunjalí,Pigai,Pigaí,Piges,Pigés,Pi...  40.90605
# 117402  Griva,Grivas,Gríva,Grívas,Kriva,Krivas,Krívas,...  40.95433
# 117410                                                NaN  44.65073
# 117462                                  Sant'Elena Irpina  41.03741
# 117463                                       Sant'Eulalia  45.81668
# 117431                                                NaN  46.15683
# 117482  Spadola,Spatula,Spàtula,si pa duo la,supadora,...  38.60378
# 117412  Sant'Andrea,Sant'Andrea Aposlolo dello Ionio,S...  38.62165
# 117422                                           Acatitla  20.95611
# 117470               Villa de Moros,Villamoras,Villamoros  24.66540
# 117452                                                NaN  20.55861
# 117418                        Puerto Mexico,Puerto México  25.17980
# 117449                                        El Vainillo  23.20611
# 117414   Mitontic,San Miguel Mitontic,San Miguel Mitontik  16.86663
# 117480                                             Palula  18.09602
# 117445  Colonia Enriquez,Colonia Enríquez,Enriquez,Enr...  19.67903
# 117429                                         Escoatitla  21.33432
# 117430  Poblado Cinco (Nuevo Villa Ojitlan),Poblado Ci...  18.43333
# 117465                              Los Merida,Los Mérida  18.38000
# 117441  Estacion de Adames,Estación de Adames,La Soled...  22.40834
# 117413                                                NaN  20.00392
# 117493                                           Tamaloya  17.38056
# 117488                                                NaN  51.49917
# 117446                                                NaN  52.78500
# 117411                                   Leverooi,Leveroy  51.24917
# 117438                                                NaN  53.19417
# 117432                                Dreischor,Drijschor  51.69000
# 117403                                                NaN  -5.30058
# 117475                                Ciepielow,Ciepielów  51.24838
# 117448              Sorkvity,Sorkwity,Sorquitten,Сорквиты  53.84569
# 117481                                                NaN  50.40414
# 117478                                                NaN  51.23151
# 117476                     Prillwitz,Przelewice,Pyrzyckie  53.10413
# 117401                                                NaN  44.86916
# 117405                                                NaN  47.66498
# 117471                                                NaN  45.10419
# 117451                                    Ratesti,Răteşti  47.58212
# 117461    Jiet,Jieti,Jietu,Jietul,Jieţ,Jieţi,Jieţu,Jieţul  45.42702
# 117427                                Maluri,Maluri-Putna  45.56138
# 117466                                        Gatka,Гатка  48.89545
# 117437              Devjatyj Val,Devyatyy Val,Девятый Вал  43.30661
# 117477                                           Suhadole  46.18333
# 117416                                         Los Santos  40.54444
# 117491                                      Villapalacios  38.57500
# 117421                                              Tales  39.94844
# 117417                                Valverde de Llerena  38.21667
# 117440                                           Holguera  39.89916
# 117408  Yaslimezar,Yaslimezar Koyu,Yaslimizar,Yaslımez...  36.97863
# 117443                                                NaN  35.98787
# 117487                               Clarence,Susan Moore  34.08371
# 117485                     Jug Town,Maurertown,Morry Town  38.92983
# 117494                                                NaN  41.85752
# 117425                         Zavoloca,Zavoloka,Заволока  48.25882
# 117435                                                NaN  56.28006
# 117486                                            Beenham  51.41624
# 117454                                            Dunston  53.15346
# 117407                          Copshaw Holm,Newcastleton  55.17908
# 117423                                        Badwell Ash  52.28333
# 117472                                                NaN  56.09765
# 117434                                                NaN  55.59683
# 117450                                                NaN  54.64548
# 117420                                                NaN  52.42333
#
#               lng iso2  cc2  admin1   admin2   admin3   admin4  population  \
# 117458  145.18690   AU  NaN      07    22670      NaN      NaN         770
# 117490  149.08333   AU  NaN      02    18230      NaN      NaN         770
# 117428   15.40236   AT   AT      03      325    32505      NaN         770
# 117484   13.20000   AT  NaN      05      504    50418      NaN         770
# 117409   14.46667   AT  NaN      04      415    41514      NaN         770
# 117424   28.81930   BY  NaN      06      NaN      NaN      NaN         770
# 117474    4.53727   BE  NaN     WAL      WNA       93    93056         770
# 117442  110.61361   CN   CN      11      NaN      NaN      NaN         770
# 117447  110.44667   CN   CN      11      NaN      NaN      NaN         770
# 117433   16.08081   HR  NaN      20  3188243      NaN      NaN         770
# 117404   13.89534   CZ  NaN      89     0426   567710      NaN         770
# 117444   16.50821   CZ  NaN      86     0534   580589      NaN         770
# 117467   17.19309   CZ  NaN      84     0713   589543      NaN         770
# 117456    2.38394   FR  NaN      32       80      803    80213         770
# 117469    1.58896   FR  NaN      32       80      801    80597         770
# 117468    1.09975   FR  NaN      24       37      373    37161         770
# 117398    1.97128   FR  NaN      76       82      822    82088         770
# 117464    7.28372   FR  NaN      44       57      576    57074         770
# 117439    3.63400   FR  NaN      32       59      592    59450         770
# 117460    2.62399   FR  NaN      11       77      772    77384         770
# 117459    3.24480   FR  NaN      11       77      773    77032         770
# 117457    2.18742   FR  NaN      32       60      601    60088         770
# 117453    5.84327   FR  NaN      84       73      732    73218         770
# 117436    1.39078   FR  NaN      24       36      361    36182         770
# 117473    4.06850   FR  NaN      84       42      421    42150         770
# 117455    0.35329   FR  NaN      24       37      372    37200         770
# 117479    1.97531   FR  NaN      32       60      601    60411         770
# 117399    3.33062   FR  NaN      32       02      023    02420         770
# 117400    6.35552   FR  NaN      84       74      742    74162         770
# 117492   -1.72857   FR  NaN      28       50      502    50594         770
# 117489   -0.42754   FR  NaN      52       49      492    49373         770
# 117406    1.80746   FR  NaN      75       19      192    19098         770
# 117483    0.68138   FR  NaN      28       61      613    61309         770
# 117419    4.62593   FR  NaN      44       08      081    08284         770
# 117426   21.72840   GR  NaN  ESYE14       22     9114      NaN         770
# 117415   24.67215   GR  NaN  ESYE11       14     9013      NaN         770
# 117402   22.41037   GR  NaN  ESYE12       06     9041      NaN         770
# 117410    7.34642   IT  NaN      12       CN   004181      NaN         770
# 117462   14.88931   IT  NaN      04       AV   064072      NaN         770
# 117463   11.81580   IT  NaN      20       TV   026004      NaN         770
# 117431   12.26495   IT  NaN      20       BL   025006      NaN         770
# 117482   16.33700   IT  NaN      03       VV   102041      NaN         770
# 117412   16.53048   IT  NaN      03       CZ   079118      NaN         770
# 117422  -98.19472   MX  NaN      30      058      NaN      NaN         770
# 117470 -107.67146   MX  NaN      25      018      NaN      NaN         770
# 117452 -101.09028   MX  NaN      11      027      NaN      NaN         770
# 117418 -100.71147   MX  NaN      19      017      NaN      NaN         770
# 117449 -106.26111   MX  NaN      25      012      NaN      NaN         770
# 117414  -92.62827   MX   MX      05      056      NaN      NaN         770
# 117480  -99.53941   MX  NaN      12      059      NaN      NaN         770
# 117445  -96.74357   MX  NaN      30      166      NaN      NaN         770
# 117429  -98.70333   MX  NaN      24      029      NaN      NaN         770
# 117430  -96.06417   MX  NaN      30      174      NaN      NaN         770
# 117465  -95.27583   MX  NaN      30      141      NaN      NaN         770
# 117441 -102.28608   MX  NaN      01      004      NaN      NaN         770
# 117413 -101.17047   MX  NaN      16      020      NaN      NaN         770
# 117493  -98.82417   MX  NaN      12      072      NaN      NaN         770
# 117488    4.56111   NL  NaN      06     0840      NaN      NaN         770
# 117446    4.86389   NL  NaN      07     1911      NaN      NaN         770
# 117411    5.84722   NL  NaN      05     0946      NaN      NaN         770
# 117438    6.78056   NL  NaN      04     1952      NaN      NaN         770
# 117432    3.98333   NL   NL      10     1676      NaN      NaN         770
# 117403  -80.69510   PE  NaN      20     2001   200105      NaN         770
# 117475   21.57475   PL  NaN      78     1409   140902      NaN         770
# 117448   21.14010   PL   PL      85     2810   281005      NaN         770
# 117481   17.90565   PL  NaN      79     1605   160502      NaN         770
# 117478   15.66771   PL  NaN      72     0201   020106      NaN         770
# 117476   15.07625   PL   PL      87     3212   321204      NaN         770
# 117401   26.11811   RO  NaN      30   135020      NaN      NaN         770
# 117405   26.66613   RO  NaN      07    35759      NaN      NaN         770
# 117471   23.36092   RO  NaN      19    79308      NaN      NaN         770
# 117451   22.88270   RO  NaN      32   136964      NaN      NaN         770
# 117461   23.42837   RO   RO      21    87077      NaN      NaN         770
# 117427   27.44033   RO   RO      40   178821      NaN      NaN         770
# 117466  140.13337   RU  NaN      30      NaN      NaN      NaN         770
# 117437  131.83839   RU  NaN      59      NaN      NaN      NaN         770
# 117477   14.55000   SI  NaN      H8      NaN      NaN      NaN         770
# 117416   -5.79774   ES  NaN      55       SA    37300      NaN         770
# 117491   -2.63384   ES  NaN      54       AB    02080      NaN         770
# 117421   -0.30719   ES  NaN      60       CS    12109      NaN         770
# 117417   -5.81667   ES  NaN      57       BA    06144      NaN         770
# 117440   -6.34999   ES  NaN      57       CC    10099      NaN         770
# 117408   38.38274   TR  NaN      63      NaN      NaN      NaN         770
# 117443  -95.13635   US  NaN      OK      021      NaN      NaN         770
# 117487  -86.42832   US  NaN      AL      009      NaN      NaN         770
# 117485  -78.46362   US  NaN      VA      171      NaN      NaN         770
# 117494  -90.92820   US  NaN      IA      031    93978      NaN         770
# 117425   25.88731   UA  NaN      03   692486      NaN      NaN         770
# 117435   -3.40027   GB  NaN     SCT       W1      NaN      NaN         770
# 117486   -1.14775   GB  NaN     ENG       P4  00MB007      NaN         770
# 117454   -0.41189   GB  NaN     ENG       H7     32UE  32UE026         770
# 117407   -2.81336   GB  NaN     SCT       T9      NaN      NaN         770
# 117423    0.91667   GB  NaN     ENG       N5     42UE  42UE008         770
# 117472   -3.40591   GB  NaN     SCT       V1      NaN      NaN         770
# 117434   -3.78084   GB  NaN     SCT       W5      NaN      NaN         770
# 117450   -2.80100   GB  NaN     ENG       C9     16UF  16UF021         770
# 117420    1.24862   GB  NaN     ENG       I9     33UH  33UH078         770
#
#                    timezone     modDate         country
# 117458  Australia/Melbourne  2019-07-18       Australia
# 117490     Australia/Sydney  2019-07-18       Australia
# 117428        Europe/Vienna  2018-07-28         Austria
# 117484        Europe/Vienna  2018-07-28         Austria
# 117409        Europe/Vienna  2018-07-28         Austria
# 117424         Europe/Minsk  2012-03-23         Belarus
# 117474      Europe/Brussels  2020-04-05         Belgium
# 117442        Asia/Shanghai  2012-01-18           China
# 117447        Asia/Shanghai  2012-01-18           China
# 117433        Europe/Zagreb  2016-12-27         Croatia
# 117404        Europe/Prague  2018-09-08         Czechia
# 117444        Europe/Prague  2019-12-29         Czechia
# 117467        Europe/Prague  2018-09-08         Czechia
# 117456         Europe/Paris  2019-03-26          France
# 117469         Europe/Paris  2016-02-18          France
# 117468         Europe/Paris  2019-03-26          France
# 117398         Europe/Paris  2020-05-07          France
# 117464         Europe/Paris  2018-07-04          France
# 117439         Europe/Paris  2016-02-18          France
# 117460         Europe/Paris  2016-02-18          France
# 117459         Europe/Paris  2016-02-18          France
# 117457         Europe/Paris  2016-12-10          France
# 117453         Europe/Paris  2016-02-18          France
# 117436         Europe/Paris  2020-06-10          France
# 117473         Europe/Paris  2019-06-05          France
# 117455         Europe/Paris  2019-03-26          France
# 117479         Europe/Paris  2016-02-18          France
# 117399         Europe/Paris  2016-02-18          France
# 117400         Europe/Paris  2019-06-05          France
# 117492         Europe/Paris  2020-06-10          France
# 117489         Europe/Paris  2019-03-26          France
# 117406         Europe/Paris  2019-04-10          France
# 117483         Europe/Paris  2016-02-18          France
# 117419         Europe/Paris  2016-02-18          France
# 117426        Europe/Athens  2015-02-07          Greece
# 117415        Europe/Athens  2014-08-17          Greece
# 117402        Europe/Athens  2019-01-20          Greece
# 117410          Europe/Rome  2014-01-11           Italy
# 117462          Europe/Rome  2014-05-20           Italy
# 117463          Europe/Rome  2014-04-13           Italy
# 117431          Europe/Rome  2014-05-04           Italy
# 117482          Europe/Rome  2014-01-11           Italy
# 117412          Europe/Rome  2014-01-11           Italy
# 117422  America/Mexico_City  2014-04-11          Mexico
# 117470     America/Mazatlan  2018-11-03          Mexico
# 117452  America/Mexico_City  2013-08-01          Mexico
# 117418    America/Monterrey  2018-11-03          Mexico
# 117449     America/Mazatlan  2014-04-11          Mexico
# 117414  America/Mexico_City  2013-08-01          Mexico
# 117480  America/Mexico_City  2018-11-03          Mexico
# 117445  America/Mexico_City  2018-11-03          Mexico
# 117429  America/Mexico_City  2018-11-03          Mexico
# 117430  America/Mexico_City  2014-04-11          Mexico
# 117465  America/Mexico_City  2014-04-11          Mexico
# 117441  America/Mexico_City  2018-11-03          Mexico
# 117413  America/Mexico_City  2018-11-03          Mexico
# 117493  America/Mexico_City  2014-04-11          Mexico
# 117488     Europe/Amsterdam  2017-10-17     Netherlands
# 117446     Europe/Amsterdam  2017-10-17     Netherlands
# 117411     Europe/Amsterdam  2017-10-17     Netherlands
# 117438     Europe/Amsterdam  2019-01-20     Netherlands
# 117432     Europe/Amsterdam  2017-10-17     Netherlands
# 117403         America/Lima  2020-05-13            Peru
# 117475        Europe/Warsaw  2010-09-17          Poland
# 117448        Europe/Warsaw  2010-09-09          Poland
# 117481        Europe/Warsaw  2010-10-20          Poland
# 117478        Europe/Warsaw  2010-09-09          Poland
# 117476        Europe/Warsaw  2011-07-31          Poland
# 117401     Europe/Bucharest  2013-04-21         Romania
# 117405     Europe/Bucharest  2013-04-21         Romania
# 117471     Europe/Bucharest  2013-04-21         Romania
# 117451     Europe/Bucharest  2013-04-21         Romania
# 117461     Europe/Bucharest  2013-04-21         Romania
# 117427     Europe/Bucharest  2013-04-21         Romania
# 117466     Asia/Vladivostok  2012-10-06          Russia
# 117437     Asia/Vladivostok  2013-10-25          Russia
# 117477     Europe/Ljubljana  2014-04-24        Slovenia
# 117416        Europe/Madrid  2012-01-19           Spain
# 117491        Europe/Madrid  2012-03-04           Spain
# 117421        Europe/Madrid  2012-07-18           Spain
# 117417        Europe/Madrid  2012-03-04           Spain
# 117440        Europe/Madrid  2012-03-04           Spain
# 117408      Europe/Istanbul  2020-07-09          Turkey
# 117443      America/Chicago  2011-05-14             USA
# 117487      America/Chicago  2017-03-09             USA
# 117485     America/New_York  2011-05-14             USA
# 117494      America/Chicago  2017-05-23             USA
# 117425          Europe/Kiev  2020-04-17         Ukraine
# 117435        Europe/London  2017-06-12  United Kingdom
# 117486        Europe/London  2017-06-12  United Kingdom
# 117454        Europe/London  2018-07-03  United Kingdom
# 117407        Europe/London  2017-06-12  United Kingdom
# 117423        Europe/London  2018-07-03  United Kingdom
# 117472        Europe/London  2017-06-15  United Kingdom
# 117434        Europe/London  2017-06-12  United Kingdom
# 117450        Europe/London  2017-06-12  United Kingdom
# 117420        Europe/London  2018-07-03  United Kingdom

# %%
city_names = gn['city'].values.tolist()
city_ascii = gn['city_ascii'].values.tolist()
city_altnames = ','.join(gn['alternateNames'].str.replace('|'.join(country_names),'').dropna().values).split(',')
city_aliases = city_names + city_ascii + city_altnames
# gn_zdup = gn.drop_duplicates('city',keep=False)
# city_names_zdup = gn_zdup['city'].values

# %%
city_to_country = dict(zip(city_names,gn['country'].values))

# %%
gn['iso2'].value_counts(normalize=True)
# Out:
# FR    0.100445
# US    0.097623
# MX    0.088567
# IT    0.076146
# DE    0.070529
#         ...
# AQ    0.000007
# GS    0.000007
# JE    0.000007
# NF    0.000007
# GI    0.000007
# Name: iso2, Length: 246, dtype: float64

# %%
gn.nunique()
# Out:
# id                147414
# city              141773
# city_ascii        140781
# alternateNames    117861
# lat               133280
# lng               136226
# iso2                 246
# cc2                  109
# admin1               592
# admin2             12842
# admin3             34066
# admin4             26561
# population         33161
# timezone             397
# modDate             3299
# country              246
# dtype: int64

# %% [markdown]
# ## Bands, genres, and location of formation

# %% [markdown]
# ### wikidata

# %%
[f for f in os.listdir("./WikiData") if f.endswith(".csv")]
# Out:
# ['recordingartist_locationofformation.csv',
#  'musicalgroup_locatedinadministrativeterritorialentity.csv',
#  'musicalgroup_genre.csv',
#  'recordingartist_countryofcitizenship.csv',
#  'musicalgroup_countryoforigin.csv',
#  'musicalgroup_locationofformation.csv',
#  'musicalgroup_country.csv']

# %%
wd = pd.DataFrame(columns=['artist'])

for csv in [f for f in os.listdir("./WikiData") if f.endswith(".csv")]:
    usecols = [1,3]
    if 'tiveterr' in csv:
        usecols = None
    df = pd.read_csv('./WikiData/'+csv,usecols=usecols,header=0)
    c0 = df.columns[0]
    df = df.rename(columns={c0: 'artist'})
    df['artist'] = df['artist'].str.strip()
    wd = pd.merge(wd,df,how="outer")
    
wd.columns = ['artist','loc_of_formation','admin_area','genre','citizenship','country','_country']
wd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102369 entries, 0 to 102368
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   artist            102369 non-null  object
#  1   loc_of_formation  21152 non-null   object
#  2   admin_area        741 non-null     object
#  3   genre             59827 non-null   object
#  4   citizenship       2974 non-null    object
#  5   country           67923 non-null   object
#  6   _country          8787 non-null    object
# dtypes: object(7)
# memory usage: 6.2+ MB

# %% [markdown]
# #### combine country into one column

# %%
mask = wd['country'].isna()
wd.loc[mask, 'country'] = wd.loc[mask, '_country']

mask = wd['country'].isna()
wd.loc[mask, 'country'] = wd.loc[mask, 'citizenship']

wd = wd.drop(['citizenship','_country'],axis=1)

# %%
wd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102369 entries, 0 to 102368
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   artist            102369 non-null  object
#  1   loc_of_formation  21152 non-null   object
#  2   admin_area        741 non-null     object
#  3   genre             59827 non-null   object
#  4   country           73326 non-null   object
# dtypes: object(5)
# memory usage: 4.7+ MB

# %% [markdown]
# #### split loc_of_formation on first comma (or a bracket) and assign 'city', 'admin_area' as appropriate

# %%
mask = (
    wd['loc_of_formation'].notna()
    &wd['loc_of_formation'].dropna().str.contains(',')
)
    
wd.update(
    wd.loc[mask,'loc_of_formation']
    .str.split(
        '[(,]',
        n=1,
        expand=True
    ).rename(
        columns={0:'loc_of_formation',
                 1:'admin_area'}))

# %% [markdown]
# #### homogenise format

# %%
wd['country'] = wd['country'].str.strip()
wd['admin_area'] = wd['admin_area'].str.strip()
wd['genre'] = wd['genre'].str.strip().str.casefold()
wd['loc_of_formation'] = wd['loc_of_formation'].str.strip()

# %%
wd = wd.replace(aliases_['country']) # catch country names in 'loc_of_formation' or 'admin_names' as well
wd['loc_of_formation'] = wd['loc_of_formation'].replace(aliases_['city'])

# %% [markdown]
# #### Remove bad names

# %%
wd.loc[wd['country'].isin(uk_country_names), 'country'] = 'United Kingdom'

# %%
# New York, USA becomes New York City, USA
wd.loc[(wd['loc_of_formation']=='New York')&(wd['country']=='USA'),'loc_of_formation'] = 'New York City'

# %% [markdown]
# #### if 'loc_of_formation' matches neither 'city_aliases' nor 'country_names' _and_ 'admin_area' is NA, let 'admin_area' = 'loc_of_formation'

# %%
mask = (wd['loc_of_formation'].notna()
        &wd['admin_area'].isna()
        &~wd['loc_of_formation'].isin(city_aliases)
        &~wd['loc_of_formation'].isin(country_names))

wd.loc[mask,'admin_area'] = wd.loc[mask,'loc_of_formation']

# %%
# Japanese prefectures in 'loc_of_formation' changed to main city instead
mask = wd['loc_of_formation'].notna()&wd['loc_of_formation'].dropna().str.endswith('Prefecture')
wd.loc[mask, 'loc_of_formation'] = wd.loc[mask, 'loc_of_formation'].apply(lambda area : area[:-11])

# %%
wd.loc[wd['loc_of_formation'].notna()&wd['country'].notna()&~wd['loc_of_formation'].isin(city_aliases)].head(100)
# Out:
#                                                   artist  \
# 2                                              Kate Bush
# 20                                                  Dean
# 25                                           Cho Kyuhyun
# 27                                  Vytautas Juozapaitis
# 28                                         Müslüm Gürses
# 56                                                  Kino
# 173                                           Bleizi Ruz
# 299                         Hillsboro Symphony Orchestra
# 355                                       Los Sabandeños
# 364                                       Desperta Ferro
# 396                                                 Acid
# 402                                         Obliteration
# 528                                             Coanegra
# 672                                                Blaze
# 696                                                Cohol
# 704                                                Xeic!
# 880                                             Pesniary
# 881                                             Pesniary
# 1532                                            Boney M.
# 1890                                      Ikimono-gakari
# 2370                                              Delain
# 2624                                             Yoomiii
# 2966                                        Dance Nation
# 3128                                       After Forever
# 3363                                                 Ark
# 3839                                           Chemistry
# 4140                                              Shaman
# 4317                                              Diesel
# 4438                                                Babe
# 4685                                       Guilt Machine
# 5075                                              Ambeon
# 5216                                       The Gathering
# 6410                            Prostitute Disfigurement
# 7007                                          Fahrenheit
# 7008                                          Fahrenheit
# 7495                                       Rascal Flatts
# 7760                                          Off Course
# 8264                                               Blond
# 8379                                                 AAA
# 8938                                       Carach Angren
# 9155                                               Focus
# 10069                                            Destine
# 10760  Deutsche Radio Philharmonie Saarbrücken Kaiser...
# 11773                                           Superfly
# 11774                                           Superfly
# 12416                                      Mrs. Einstein
# 12645                       Original Dixieland Jass Band
# 14084                                                 HY
# 15101                                          Enthroned
# 15138                                          Happy End
# 16707                                          Gouryella
# 16741                                            Flairck
# 18040                                      The Outsiders
# 19637                                           Star One
# 20536                                           Neiokõsõ
# 21115                                       Mustard Plug
# 21727                                     Kingfisher Sky
# 21863                               Legion of the Damned
# 21906                                             Treble
# 23901                          De Jeugd van Tegenwoordig
# 25349                                       Schleim-Keim
# 26201                                 The Gerogerigegege
# 26746                                          Hana*Hana
# 27605                                            Il Volo
# 27606                                            Il Volo
# 28005                                              Mayan
# 31024                                         Touchstone
# 31025                                         Touchstone
# 32316                                           Pragaash
# 32628                                    Music Band Duna
# 32629                                    Music Band Duna
# 33426                                           NuAngels
# 35048                                               Kulp
# 36961                                           Sonic Me
# 39560                                             ReVamp
# 39709                                         Wonderland
# 41352                                   Ensemble Unicorn
# 54014                                  Tom Fun Orchestra
# 54640                                 Conjunto Big Brasa
# 55234                                             Indigo
# 57515                                          SCK GIRLS
# 58761                                            Moudoku
# 58832                                          Q11639491
# 59006                                               Òwix
# 59380                                           Akelarre
# 59456                                               E-76
# 60512                                         Numero Uno
# 61746                                      Systema Solar
# 62357                                          Wolf Down
# 63019                                              Arion
# 64994                                              Herod
# 68185                                          Lindemann
# 68186                                          Lindemann
# 68494                                             Musnok
# 68596                        Ansambel Tonija Verderberja
# 69530                                          Snakehips
# 71065                                                BQL
# 71488                                        Guilty Kiss
# 71533                                             Sumika
# 71958                                            Arizona
#
#                              loc_of_formation  \
# 2                              English people
# 20                                South Korea
# 25                                South Korea
# 27                                  Lithuania
# 28                         Şanlıurfa Province
# 56                             United Kingdom
# 173                                  Brittany
# 299                                       USA
# 355                            Canary Islands
# 364                         Catalan Countries
# 396                                     Japan
# 402                                   Kolbotn
# 528                      Santa Maria del Camí
# 672                                       USA
# 696                                  Kanagawa
# 704                          Terres de l'Ebre
# 880    Byelorussian Soviet Socialist Republic
# 881    Byelorussian Soviet Socialist Republic
# 1532                              West Indies
# 1890                                 Kanagawa
# 2370                              Netherlands
# 2624                                  Germany
# 2966                              Netherlands
# 3128                              Netherlands
# 3363                                    Toten
# 3839                                    Japan
# 4140                                  Finland
# 4317                              Netherlands
# 4438                              Netherlands
# 4685                              Netherlands
# 5075                              Netherlands
# 5216                              Netherlands
# 6410                              Netherlands
# 7007                                   Taiwan
# 7008                                   Taiwan
# 7495                                     Ohio
# 7760                                    Japan
# 8264                                   Sweden
# 8379                                    Japan
# 8938                                Landgraaf
# 9155                              Netherlands
# 10069                             Netherlands
# 10760                                Saarland
# 11773                                   Japan
# 11774                                 Imabari
# 12416                             Netherlands
# 12645                                     USA
# 14084                                   Uruma
# 15101                 Brussels-Capital Region
# 15138                              Chiyoda-ku
# 16707                             Netherlands
# 16741                             Netherlands
# 18040                               Wimbledon
# 19637                             Netherlands
# 20536                                 Estonia
# 21115                                Michigan
# 21727                             Netherlands
# 21863                             Netherlands
# 21906                             Netherlands
# 23901                             Netherlands
# 25349                            Stotternheim
# 26201                             Shinjuku-ku
# 26746                                   Hyōgo
# 27605                                  Sicily
# 27606                                  Sicily
# 28005                             Netherlands
# 31024                          North Carolina
# 31025                           Hertfordshire
# 32316                       Jammu and Kashmir
# 32628                             Dolgoprudny
# 32629                             Dolgoprudny
# 33426                                 Ukraine
# 35048                                  Turkey
# 36961                             Netherlands
# 39560                             Netherlands
# 39709                     Tyresö Municipality
# 41352                                 Austria
# 54014                      Cape Breton Island
# 54640                               Messejana
# 55234                                Slovenia
# 57515                                  Miyagi
# 58761                                Kanagawa
# 58832                                Kanagawa
# 59006                     Callosa d'en Sarrià
# 59380         Soraluze-Placencia de las Armas
# 59456                                   Vinje
# 60512                             Netherlands
# 61746                                 Taganga
# 62357                                    Ruhr
# 63019                                 Finland
# 64994                                     USA
# 68185                                 Germany
# 68186                                 Germany
# 68494                                 Majorca
# 68596                      Stari trg ob Kolpi
# 69530                          United Kingdom
# 71065                Municipality of Prevalje
# 71488                                   Japan
# 71533                                Kanagawa
# 71958                              New Jersey
#
#                                    admin_area genre         country
# 2                              English people   NaN  United Kingdom
# 20                                        NaN   NaN     South Korea
# 25                                        NaN   NaN     South Korea
# 27                                        NaN   NaN       Lithuania
# 28                         Şanlıurfa Province   NaN          Turkey
# 56                                        NaN   NaN    Soviet Union
# 173                                  Brittany   NaN          France
# 299                                       NaN   NaN             USA
# 355                            Canary Islands   NaN           Spain
# 364                         Catalan Countries   NaN           Spain
# 396                                       NaN   NaN         Belgium
# 402                                   Kolbotn   NaN          Norway
# 528                      Santa Maria del Camí   NaN           Spain
# 672                                       NaN   NaN           Japan
# 696                       Kanagawa Prefecture   NaN           Japan
# 704                          Terres de l'Ebre   NaN           Spain
# 880    Byelorussian Soviet Socialist Republic   NaN         Belarus
# 881    Byelorussian Soviet Socialist Republic   NaN    Soviet Union
# 1532                              West Indies   NaN     Netherlands
# 1890                      Kanagawa Prefecture   NaN           Japan
# 2370                                      NaN   NaN     Netherlands
# 2624                                      NaN   NaN     Netherlands
# 2966                                      NaN   NaN     Netherlands
# 3128                                      NaN   NaN     Netherlands
# 3363                                    Toten   NaN  United Kingdom
# 3839                                      NaN   NaN           Japan
# 4140                                      NaN   NaN          Brazil
# 4317                                      NaN   NaN     Netherlands
# 4438                                      NaN   NaN     Netherlands
# 4685                                      NaN   NaN     Netherlands
# 5075                                      NaN   NaN     Netherlands
# 5216                                      NaN   NaN     Netherlands
# 6410                                      NaN   NaN     Netherlands
# 7007                                      NaN   NaN          Taiwan
# 7008                                      NaN   NaN           Chile
# 7495                                     Ohio   NaN             USA
# 7760                                      NaN   NaN           Japan
# 8264                                      NaN   NaN          Sweden
# 8379                                      NaN   NaN           Japan
# 8938                                Landgraaf   NaN     Netherlands
# 9155                                      NaN   NaN     Netherlands
# 10069                                     NaN   NaN     Netherlands
# 10760                                Saarland   NaN         Germany
# 11773                                     NaN   NaN           Japan
# 11774                                 Imabari   NaN           Japan
# 12416                                     NaN   NaN     Netherlands
# 12645                                     NaN   NaN             USA
# 14084                                   Uruma   NaN           Japan
# 15101                 Brussels-Capital Region   NaN         Belgium
# 15138                              Chiyoda-ku   NaN           Japan
# 16707                                     NaN   NaN     Netherlands
# 16741                                     NaN   NaN     Netherlands
# 18040                               Wimbledon   NaN     Netherlands
# 19637                                     NaN   NaN     Netherlands
# 20536                                     NaN   NaN         Estonia
# 21115                                Michigan   NaN             USA
# 21727                                     NaN   NaN     Netherlands
# 21863                                     NaN   NaN     Netherlands
# 21906                                     NaN   NaN     Netherlands
# 23901                                     NaN   NaN     Netherlands
# 25349                            Stotternheim   NaN         Germany
# 26201                             Shinjuku-ku   NaN           Japan
# 26746                        Hyōgo Prefecture   NaN           Japan
# 27605                                  Sicily   NaN           Italy
# 27606                                  Sicily   NaN           Italy
# 28005                                     NaN   NaN     Netherlands
# 31024                          North Carolina   NaN  United Kingdom
# 31025                           Hertfordshire   NaN  United Kingdom
# 32316                       Jammu and Kashmir   NaN           India
# 32628                             Dolgoprudny   NaN          Russia
# 32629                             Dolgoprudny   NaN    Soviet Union
# 33426                                     NaN   NaN         Ukraine
# 35048                                     NaN   NaN          Turkey
# 36961                                     NaN   NaN     Netherlands
# 39560                                     NaN   NaN     Netherlands
# 39709                     Tyresö Municipality   NaN        Portugal
# 41352                                     NaN   NaN         Austria
# 54014                      Cape Breton Island   NaN          Canada
# 54640                               Messejana   NaN          Brazil
# 55234                                     NaN   NaN        Portugal
# 57515                       Miyagi Prefecture   NaN           Japan
# 58761                     Kanagawa Prefecture   NaN           Japan
# 58832                     Kanagawa Prefecture   NaN           Japan
# 59006                     Callosa d'en Sarrià   NaN           Spain
# 59380         Soraluze-Placencia de las Armas   NaN           Spain
# 59456                                   Vinje   NaN          Norway
# 60512                                     NaN   NaN     Netherlands
# 61746                                 Taganga   NaN        Colombia
# 62357                                    Ruhr   NaN         Germany
# 63019                                     NaN   NaN          Brazil
# 64994                                     NaN   NaN          Brazil
# 68185                                     NaN   NaN          Sweden
# 68186                                     NaN   NaN         Germany
# 68494                                 Majorca   NaN           Spain
# 68596                      Stari trg ob Kolpi   NaN        Slovenia
# 69530                                     NaN   NaN  United Kingdom
# 71065                Municipality of Prevalje   NaN        Slovenia
# 71488                                     NaN   NaN           Japan
# 71533                     Kanagawa Prefecture   NaN           Japan
# 71958                              New Jersey   NaN             USA

# %% [markdown]
# #### transpose "admin_area" if it matches a country or city name, and delete if it matches a country name

# %%
mask = ((wd['loc_of_formation'].isna()
        |~wd['loc_of_formation'].isin(city_aliases))
        &wd['admin_area'].notna()
        &wd['admin_area'].isin(city_aliases)
        &~wd['admin_area'].dropna().isin(country_names+uk_country_names))
wd.loc[mask,'loc_of_formation'] = wd.loc[mask, 'admin_area']

mask = ((wd['country'].isna())
        &wd['admin_area'].notna()
        &wd['admin_area'].dropna().isin(country_names+uk_country_names))
wd.loc[mask,'country'] = wd.loc[mask, 'admin_area']
wd.loc[mask,'admin_area'] = np.NaN

# %% [markdown]
# #### Get admin_area based on existing 'loc_of_formation'+'country' info

# %%
# loc_area_country = wd.loc[
#     wd['loc_of_formation']
#     .notna()
#     &wd['admin_area']
#     .notna()
#     &wd['country']
#     .notna()
#     &wd['loc_of_formation'].isin(wd.loc[wd['admin_area'].isna(),'loc_of_formation'].values)
#     &wd['country'].isin(wd.loc[wd['admin_area'].isna(),'country'].values),
#     ['loc_of_formation','admin_area','country']
# ].drop_duplicates(['loc_of_formation','country'], keep=False)

# %%
# loccountry_to_admin = dict(zip(loc_area_country['loc_of_formation']+loc_area_country['country'],loc_area_country['admin_area']))

# %%
# sub_df = wd.loc[
#     wd['admin_area']
#     .isna()
#     &wd['loc_of_formation']
#     .isin(loc_area_country['loc_of_formation'].values)
#     &wd['country']
#     .isin(loc_area_country['country'].values),
#     ['loc_of_formation','admin_area','country']
# ]

# concat = sub_df['loc_of_formation']+sub_df['country']


# # (wd['loc_of_formation']+wd['admin_area']).replace(locarea_to_country)

# %%
# concat.replace(loccountry_to_admin)

# %%
# wd.loc[
#     wd['admin_area']
#     .isna()
#     &wd['loc_of_formation']
#     .isin(loc_area_country['loc_of_formation'].values)
#     &wd['country']
#     .isin(loc_area_country['country'].values),
#     'admin_area'
# ] = concat.replace(loccountry_to_admin)

# %% [markdown]
# #### Get country based on existing 'loc_of_formation'+'admin_area' info

# %%
loc_area_country = wd.loc[
    wd['loc_of_formation']
    .notna()
    &wd['admin_area']
    .notna()
    &wd['country']
    .notna()
    &wd['loc_of_formation'].isin(wd.loc[wd['country'].isna(),'loc_of_formation'].values)
    &wd['admin_area'].isin(wd.loc[wd['country'].isna(),'admin_area'].values),
    ['loc_of_formation','admin_area','country']
].drop_duplicates(['loc_of_formation','admin_area'], keep=False)

# %%
locarea_to_country = dict(zip(loc_area_country['loc_of_formation']+loc_area_country['admin_area'],loc_area_country['country']))

# %%
sub_df = wd.loc[
    wd['country']
    .isna()
    &wd['loc_of_formation']
    .isin(loc_area_country['loc_of_formation'].values)
    &wd['admin_area']
    .isin(loc_area_country['admin_area'].values),
    ['loc_of_formation','admin_area','country']
]

concat = sub_df['loc_of_formation']+sub_df['admin_area']


# (wd['loc_of_formation']+wd['admin_area']).replace(locarea_to_country)

# %%
wd.loc[
    wd['country']
    .isna()
    &wd['loc_of_formation']
    .isin(loc_area_country['loc_of_formation'].values)
    &wd['admin_area']
    .isin(loc_area_country['admin_area'].values),
    'country'
] = concat.replace(locarea_to_country)

# %% [markdown]
# #### transpose loc_of_formation and country to other instances of same artist (diff. genres perhaps)

# %%
mask = (wd['loc_of_formation'].notna()
       &wd['artist'].str.casefold().isin(wd.loc[wd['loc_of_formation'].isna(),'artist'].str.casefold().values))

arc = wd.loc[mask,['artist','loc_of_formation']].sort_values(['loc_of_formation']).drop_duplicates(['artist'])

artist_to_city = dict(
    zip(
        arc['artist'].str.casefold().values,
        arc['loc_of_formation'].values
    )
)

# mask = (wd['country'].notna()
#        &wd['artist'].str.casefold().isin(wd.loc[wd['country'].isna(),'artist'].str.casefold().values))

# arc = wd.loc[mask,['artist','country']].sort_values(['country']).drop_duplicates(['artist'])

# artist_to_country = dict(
#     zip(
#         arc['artist'].str.casefold().values,
#         arc['country'].values
#     )
# )

# %%
mask = (wd['loc_of_formation'].isna()
        &wd['artist'].str.casefold().isin(artist_to_city.keys()))

wd.loc[mask,'loc_of_formation'] = wd.loc[mask,'artist'].str.casefold().replace(artist_to_city)

# mask = (wd['country'].isna()
#         &wd['artist'].str.casefold().isin(artist_to_country.keys()))

# wd.loc[mask,'country'] = wd.loc[mask,'artist'].str.casefold().replace(artist_to_country)

# %% [markdown]
# #### get country based on existing 'loc_of_formation' OR 'admin_area' information

# %%
# area_to_country = dict(
#     wd.loc[
#         wd['admin_area']
#         .notna()
#         &wd['country']
#         .notna()
#         &wd['admin_area']
#         .isin(wd.loc[
#             wd['country'].isna(),
#             'admin_area'
#         ].values),
#         ['admin_area','country']
#     ].drop_duplicates(['admin_area'], keep=False).values
# )

# mask = wd['country'].isna()&wd['admin_area'].notna()&wd['admin_area'].isin(area_to_country.keys())
# wd.loc[mask, 'country'] = wd.loc[mask, 'admin_area'].replace(area_to_country)

# %%
# wd_city_to_country = dict(
#     wd.loc[
#         wd['loc_of_formation']
#         .notna()
#         &wd['country']
#         .notna()
#         &wd['loc_of_formation']
#         .isin(wd.loc[
#             wd['country'].isna(),
#             'loc_of_formation'
#         ].values),
#         ['loc_of_formation','country']
#     ].drop_duplicates(['loc_of_formation','country']).values
# )

# mask = wd['country'].isna()&wd['loc_of_formation'].notna()&wd['loc_of_formation'].isin(wd_city_to_country.keys())
# wd.loc[mask, 'country'] = wd.loc[mask, 'loc_of_formation'].replace(wd_city_to_country)

# %% [markdown]
# #### country from external cities or admin areas

# %%
# Japan from prefecture
mask = (wd['loc_of_formation'].notna()
        &(wd['loc_of_formation'].dropna().str.endswith('Prefecture')
        |wd['admin_area'].dropna().str.endswith('Prefecture')))

wd.loc[mask, 'country'] = 'Japan'

# %%
wd.loc[wd['country'].isna()&((wd['loc_of_formation'].isin(uk_country_names))|(wd['admin_area'].isin(uk_country_names))),'country'] = 'United Kingdom'

# %%
wd.loc[wd['country'].isna()&((wd['loc_of_formation'].isin(us_state_names))|(wd['admin_area'].isin(us_state_names))), 'country'] = 'USA'

# %%
wd.loc[wd['country'].isna()&((wd['loc_of_formation'].isin(uk_county_names))|(wd['admin_area'].isin(uk_county_names))), 'country'] = 'United Kingdom'

# %%
wd.loc[wd['country'].isna()&((wd['loc_of_formation'].isin(us_county_names))|(wd['admin_area'].isin(us_county_names))), 'country'] = 'USA'

# %%
mask = wd['country'].isna()&wd['loc_of_formation'].isin(city_to_country.keys())
wd.loc[mask, 'country'] = wd.loc[mask, 'loc_of_formation'].replace(city_to_country)

mask = wd['country'].isna()&wd['admin_area'].isin(city_to_country.keys())
wd.loc[mask, 'country'] = wd.loc[mask, 'admin_area'].replace(city_to_country)

# %%
# print('city_to_country: ',len(city_to_country),'\nwd_city_to_country: ',len(wd_city_to_country),'\narea_to_country: ',len(area_to_country))

# %%
wd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102369 entries, 0 to 102368
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   artist            102369 non-null  object
#  1   loc_of_formation  50532 non-null   object
#  2   admin_area        2663 non-null    object
#  3   genre             59827 non-null   object
#  4   country           92916 non-null   object
# dtypes: object(5)
# memory usage: 9.7+ MB

# %% [markdown]
# #### tidy up where possible

# %%
wd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102369 entries, 0 to 102368
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   artist            102369 non-null  object
#  1   loc_of_formation  50532 non-null   object
#  2   admin_area        2663 non-null    object
#  3   genre             59827 non-null   object
#  4   country           91749 non-null   object
#  5   city              0 non-null       float64
# dtypes: float64(1), object(5)
# memory usage: 10.5+ MB

# %%
wd.loc[~wd['country'].isin(country_names), 'country'] = np.nan
wd.loc[~wd['loc_of_formation'].isin(city_aliases), 'loc_of_formation'] = np.nan

# %%
city_states = gn.loc[gn['city']==gn['country'], 'city'].unique()
wd.loc[wd['country'].isna()&wd['loc_of_formation'].isin(city_states), 'country'] = wd.loc[wd['loc_of_formation'].isin(city_states), 'loc_of_formation']
wd.loc[wd['loc_of_formation'].isna()&wd['country'].isin(city_states), 'loc_of_formation'] = wd.loc[wd['country'].isin(city_states), 'country']

# %% [markdown]
# #### finishing

# %%
wd = wd[(~(wd['loc_of_formation']==wd['country']))
        |(wd['loc_of_formation'].isin(city_states))]

# %%
wd['admin_area'] = wd['admin_area'].str.strip()

# %%
wd = wd.dropna(subset=['loc_of_formation','country'])

# %%
wd = wd.drop_duplicates()

# %%
wd = wd.rename(columns={'loc_of_formation': 'city'})

# %%
wd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42232 entries, 0 to 102289
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   artist      42232 non-null  object
#  1   city        42232 non-null  object
#  2   admin_area  1090 non-null   object
#  3   genre       23053 non-null  object
#  4   country     42232 non-null  object
# dtypes: object(5)
# memory usage: 1.9+ MB

# %%
wd.sort_values('city').drop_duplicates('artist').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18968 entries, 517 to 56881
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   artist      18968 non-null  object
#  1   city        18968 non-null  object
#  2   admin_area  606 non-null    object
#  3   genre       8769 non-null   object
#  4   country     18968 non-null  object
# dtypes: object(5)
# memory usage: 889.1+ KB

# %%
wd.nunique()
# Out:
# artist        18968
# city           2953
# admin_area      253
# genre           792
# country         141
# dtype: int64

# %%
wd['country'].value_counts(normalize=True)
# Out:
# USA               0.410210
# United Kingdom    0.124100
# Japan             0.046884
# Canada            0.036299
# Australia         0.034784
#                     ...
# Gambia            0.000024
# Tajikistan        0.000024
# Iraq              0.000024
# Maldives          0.000024
# El Salvador       0.000024
# Name: country, Length: 141, dtype: float64

# %% [markdown]
# ### trebi/Spotify

# %% [markdown]
# #### (songs)

# %%
ts = pd.read_csv('./trebi/csv/songs.csv',
                 sep=';',
                 usecols=[0,2,4],
                 header=0,
                 names=['songID','artist','genre'])

ts['genre'] = ts['genre'].str.strip().str.casefold()

ts['artist'] = ts['artist'].str.split(', ')
ts = ts.explode('artist',ignore_index=True)
ts['artist'] = ts['artist'].str.strip()

ts = ts.drop_duplicates(['artist','genre'])

# %%
ts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 292566 entries, 0 to 357995
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   songID  292566 non-null  object
#  1   artist  292566 non-null  object
#  2   genre   292566 non-null  object
# dtypes: object(3)
# memory usage: 8.9+ MB

# %%
ts.nunique()
# Out:
# songID    166627
# artist    177656
# genre       1496
# dtype: int64

# %%
song_to_artist = dict(ts[['songID','artist']].drop_duplicates('songID').values)
len(song_to_artist)
# Out:
# 166627

# %% [markdown]
# #### trebi tag

# %%
# tt = pd.read_csv('./trebi/csv/tags.csv', sep=';', usecols=[0,1], names=['songID','genre'])
# tt = tt.drop_duplicates()
# tt = tt.loc[tt['songID'].isin(ts['songID'].values)]
# tt['genre'] = tt['genre'].str.strip().str.casefold()
# tt['artist'] = tt['songID'].replace(song_to_artist)

# %%
# tt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47105 entries, 1 to 989696
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   songID  47105 non-null  object
#  1   genre   47105 non-null  object
#  2   artist  47105 non-null  object
# dtypes: object(3)
# memory usage: 1.4+ MB

# %%
# tt.nunique()
# Out:
# songID    47105
# genre      1476
# artist    43641
# dtype: int64

# %% [markdown]
# #### trebi merge

# %%
tstt = ts
# pd.merge(ts, tt, how='outer').drop_duplicates(['artist','genre'])

# %%
tstt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 292566 entries, 0 to 292565
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   songID  292566 non-null  object
#  1   artist  292566 non-null  object
#  2   genre   292566 non-null  object
# dtypes: object(3)
# memory usage: 8.9+ MB

# %%
tstt.nunique()
# Out:
# songID    166627
# artist    177656
# genre       1496
# dtype: int64

# %% [markdown]
# ## merge trebi and wikidata

# %%
lkey = wd['artist'].str.casefold()
rkey = tstt['artist'].str.casefold()

df = pd.merge(wd,tstt,left_on=lkey,right_on=rkey,how='outer')

# %%
df.loc[df['artist_x'].isna(), 'artist_x'] = df.loc[df['artist_x'].isna(), 'artist_y']

# %%
df = df.melt(
    ['artist_x','city','admin_area','country','songID'],
    ['genre_x','genre_y'],
    value_name='genre'
).drop(
    'variable',axis=1
).rename(
    columns={'artist_x': 'artist'}
).drop_duplicates(
    ['artist','city','country','genre']
).dropna(
    subset=['city','country','genre'],
    how='all'
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 345329 entries, 0 to 714293
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   artist      345329 non-null  object
#  1   city        80383 non-null   object
#  2   admin_area  1531 non-null    object
#  3   country     80383 non-null   object
#  4   songID      322772 non-null  object
#  5   genre       323659 non-null  object
# dtypes: object(6)
# memory usage: 18.4+ MB

# %% [markdown]
# ### reinterpret some genres

# %%
hyphens = df['genre'].str.contains("-", na=False)
nohy = df.loc[~hyphens,'genre'].values
mask = df['genre'].str.replace("-"," ").isin(nohy)
df.loc[hyphens&mask,'genre'] = df.loc[hyphens&mask,'genre'].str.replace("-"," ")

# %%
df['genre'] = df['genre'].str.replace("hip hop", "hip-hop")
df['genre'] = df['genre'].str.replace("rock steady", "rocksteady")

# %%
demonyms = ['anatolian', 'argentine', 'basque',
            'boston', 'brazilian', 'bulgarian', 'catalan',
            'chilean', 'colombian', 'czech', 'dutch',
            'french', 'hungarian', 'indian',
            'kiwi', 'kraut', 'norwegian', 'peruvian', 'portuguese',
            'romanian', 'russian', 'scottish', 'slovenian', 'spanish',
            'suomi', 'swiss', 'swedish', 'turkish', 'ukrainian', 'venezuelan',
            'welsh', 'yugoslav','slovak','estonian','icelandic',
            'indonesian', 'albuquerque', 'canadian', 'la',
            'vancouver', 'australian', 'perth', 'german', 'brooklyn',
            'vienna', 'portland', 'vegas', 'mexican', 'sheffield',
            'ok', 'rva', 'athens', 'belgian',
            'slc', 'finnish', 'chicago', 'polish', 'seattle',
            'leeds', 'nz', 'thai', 'louisville', 'danish',
            'denver', 'michigan', 'stl', 'kc', 'triangle',
            'greek', 'irish', 'bay area', 'thai', 'pakistani',
            'polynesian', 'latvian', 'arab', 'korean', 'brazilian',
            'taiwanese', 'faroese', 'austrian', 'persian', 'chinese',
            'italian', 'american', 'puerto rican', 'detroit', 'louisiana',
            'new orleans', 'uk', 'british'
           ]

# %%
sorted(demonyms)
# Out:
# ['albuquerque',
#  'american',
#  'anatolian',
#  'arab',
#  'argentine',
#  'athens',
#  'australian',
#  'austrian',
#  'basque',
#  'bay area',
#  'belgian',
#  'boston',
#  'brazilian',
#  'brazilian',
#  'british',
#  'brooklyn',
#  'bulgarian',
#  'canadian',
#  'catalan',
#  'chicago',
#  'chilean',
#  'chinese',
#  'colombian',
#  'czech',
#  'danish',
#  'denver',
#  'detroit',
#  'dutch',
#  'estonian',
#  'faroese',
#  'finnish',
#  'french',
#  'german',
#  'greek',
#  'hungarian',
#  'icelandic',
#  'indian',
#  'indonesian',
#  'irish',
#  'italian',
#  'kc',
#  'kiwi',
#  'korean',
#  'kraut',
#  'la',
#  'latvian',
#  'leeds',
#  'louisiana',
#  'louisville',
#  'mexican',
#  'michigan',
#  'new orleans',
#  'norwegian',
#  'nz',
#  'ok',
#  'pakistani',
#  'persian',
#  'perth',
#  'peruvian',
#  'polish',
#  'polynesian',
#  'portland',
#  'portuguese',
#  'puerto rican',
#  'romanian',
#  'russian',
#  'rva',
#  'scottish',
#  'seattle',
#  'sheffield',
#  'slc',
#  'slovak',
#  'slovenian',
#  'spanish',
#  'stl',
#  'suomi',
#  'swedish',
#  'swiss',
#  'taiwanese',
#  'thai',
#  'thai',
#  'triangle',
#  'turkish',
#  'uk',
#  'ukrainian',
#  'vancouver',
#  'vegas',
#  'venezuelan',
#  'vienna',
#  'welsh',
#  'yugoslav']

# %%
hiphop_mask = df['genre'].str.contains('hip-hop',na=False)
for nym in demonyms:
    mask = df['genre'].str.contains(nym,na=False)&~hiphop_mask
    match = df.loc[mask,'genre'].str.extract('(.*)('+nym+'[ -])(.*)')
    df.loc[mask,'genre'] = (match[0]+match[2]).str.strip()

# %%
mask = df['genre'].str.contains("music$",na=False)

df.loc[mask,'genre'] = df.loc[mask,'genre'].str.extract("(.*)([ -]music$)")[0]

# %%
df.loc[df['genre'].str.contains('(?<!deep) indie$',na=False),'genre'] = 'indie'

df.loc[df['genre'].notna()&df['genre'].str.contains(r'electronic dance'), 'genre'] = 'edm'

df.loc[df['genre'].str.contains('[ -]singer[- ]songwriter',na=False),'genre'] = 'singer-songwriter'

# %%
df = df.drop_duplicates(['artist','genre'])

# %%
df.loc

# %% [markdown]
# ### fill in cities

# %%
mask = df['city'].isna()&df['artist'].str.casefold().isin(artist_to_city.keys())
df.loc[mask,'city'] = df.loc[mask,'artist'].str.casefold().replace(artist_to_city)

# mask = df['country'].isna()&df['artist'].str.casefold().isin(artist_to_country.keys())
# df.loc[mask,'country'] = df.loc[mask,'artist'].str.casefold().replace(artist_to_country)

# %%
df = df.loc[(df['city'].isin(city_aliases))]

# %%
df = df.drop_duplicates(['artist','genre'])

# %%
df = df.dropna(subset=['genre','city'])

# %%
# mask = df['country'].isna()&df['city'].isin(wd_city_to_country.keys())
# df.loc[mask, 'country'] = df.loc[mask, 'city'].replace(wd_city_to_country)

# %%
mask = df['country'].isna()&df['city'].isin(city_to_country.keys())
df.loc[mask, 'country'] = df.loc[mask, 'city'].replace(city_to_country)

# %%
df.loc[df['country'].isna()].value_counts('city')
# Out:
# city
# Canada                          27
# Special Region of Yogyakarta     4
# Plzeň                            3
# Brașov                           2
# Thessaloniki                     1
# Portrane                         1
# Darjeeling                       1
# Chișinău                         1
# Aarhus                           1
# dtype: int64

# %%
df = df.dropna(subset=['country'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43766 entries, 37 to 627664
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   artist      43766 non-null  object
#  1   city        43766 non-null  object
#  2   admin_area  526 non-null    object
#  3   country     43766 non-null  object
#  4   songID      34452 non-null  object
#  5   genre       43766 non-null  object
# dtypes: object(6)
# memory usage: 2.3+ MB

# %%
df.nunique()
# Out:
# artist        16614
# city           2717
# admin_area      150
# country         125
# songID        10784
# genre          1352
# dtype: int64

# %%
failed = []
for city, country in df[['city','country']].drop_duplicates().values:
    try:
        df.loc[
            (df['city']==city)
            &(df['country']==country),
            ['lat','lng','population']
        ] = gn.loc[
            (gn['alternateNames'].str.casefold().str.contains(city.casefold(),na=False))
            &(gn['country'].str.casefold()==country.casefold()),
            ['lat','lng', 'population']
        ].values[0]
    except:
        failed.append(tuple([city, country]))
len(failed)
# Out:
# /Users/Nathan/opt/anaconda3/lib/python3.7/site-packages/pandas/core/strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %%
df = df.dropna(subset=['lat','lng','population'])

# %%
df = df.loc[df['population']>0.0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41160 entries, 37 to 627035
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   artist      41160 non-null  object
#  1   city        41160 non-null  object
#  2   admin_area  447 non-null    object
#  3   country     41160 non-null  object
#  4   songID      32407 non-null  object
#  5   genre       41160 non-null  object
#  6   lat         41160 non-null  float64
#  7   lng         41160 non-null  float64
#  8   population  41160 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 3.1+ MB

# %%
df.value_counts('genre')
# Out:
# genre
# rock                    1904
# alternative rock        1769
# punk rock               1567
# indie rock              1316
# pop                     1127
#                         ...
# japanese traditional       1
# jazz bass                  1
# jazz brass                 1
# jazz composition           1
# abstract                   1
# Length: 1329, dtype: int64

# %%
df.nunique()
# Out:
# artist        15688
# city           2393
# admin_area      136
# country         125
# songID        10165
# genre          1329
# lat            2441
# lng            2445
# population     2429
# dtype: int64

# %% [markdown]
# ## Map

# %%
import folium

from folium.plugins import marker_cluster

# %%
# genre = 'k-pop'
# if genre in tlgs:
#     value_counts = df.loc[df['genre'].str.contains(genre,na=False)].drop_duplicates(['artist']).value_counts(['city','country','lat','lng','population'])
# else:
#     value_counts = df.loc[df['genre']==genre].drop_duplicates(['artist']).value_counts(['city','country','lat','lng','population'])

# value_counts = value_counts.loc[value_counts > 5]
# total_genre_bands = value_counts.sum()

# bands_per_million = (value_counts / (value_counts.index.get_level_values('population') / 1000000))
# people_per_band = (value_counts.index.get_level_values('population') / value_counts)
# one_in_x = (city_band_count[value_counts.index] / value_counts)

# city, country, la, lo, po = one_in_x.idxmin()
# one_in_x = one_in_x.min()

# count = value_counts[city,country,la,lo,po]
# bands_per_million = bands_per_million[city,country,la,lo,po]
# people_per_band = people_per_band[city,country,la,lo,po]
# all_bands_here = city_band_count[city,country]

# %%
homes_of = []
failed = []

letters = '[^\s'+punctuation.replace('&','')+']+'
word = letters+'-?'+letters
tlg_mask = df['genre'].str.fullmatch(letters+'-?'+letters,na=False)
tlgs = df.loc[tlg_mask,'genre'].value_counts()
tlgs = tlgs.loc[tlgs > 12].index

city_band_count = df.drop_duplicates('artist').value_counts(['city','country'])

for genre in df['genre'].value_counts().loc[df['genre'].value_counts() > 12].index.tolist():
    if genre in tlgs:
        value_counts = df.loc[df['genre'].str.contains(genre,na=False)].drop_duplicates(['artist']).value_counts(['city','country','lat','lng','population'])
    else:
        value_counts = df.loc[df['genre']==genre].drop_duplicates(['artist']).value_counts(['city','country','lat','lng','population'])

    value_counts = value_counts.loc[value_counts > 5]
    total_genre_bands = value_counts.sum()
    
    if len(value_counts) == 0:
        failed.append(genre)
        continue
        
    bands_per_million = (value_counts / (value_counts.index.get_level_values('population') / 1000000))
    people_per_band = (value_counts.index.get_level_values('population') / value_counts)
    one_in_x = (city_band_count[value_counts.index] / value_counts)
    
    city, country, la, lo, po = one_in_x.idxmin()
    one_in_x = one_in_x.min()
    
    count = value_counts[city,country,la,lo,po]
    bands_per_million = bands_per_million[city,country,la,lo,po]
    people_per_band = people_per_band[city,country,la,lo,po]
    all_bands_here = city_band_count[city,country]
    
    
    homes_of.append(tuple(
        [
            genre,
            count,
            city,
            country,
            bands_per_million,
            people_per_band,
            one_in_x,
            all_bands_here,
            total_genre_bands,
            la.round(5),
            lo.round(5)
        ]
    ))

# %%
len(homes_of)
# Out:
# 244

# %%
len(failed)
# Out:
# 202

# %%
m2 = folium.Map(location=[51, 0.3],
              zoom_start=5)

locations = []
popups = []

for ge, num, ci, co, bpm, ppb, oix, abh, tgb, la, lo in homes_of:
    
    sd = -(len(str(int(ppb)))-2)

    popup = folium.Popup(
        f"<p style='white-space:nowrap'>{ci} ({co}) is the modern home of: <strong>{ge}</strong><br/>\
        1 in {int(round(oix,0))} bands from {ci} is a {ge} band (one for every ~{int(round(ppb, sd)):n} people)<br/><br/>\
        <em>In this dataset, there are…\
        <ul><li>{num} {ge} bands from {ci} ({int(round(num / tgb * 100, 0))}% of all {ge} bands)\
        <li>{abh} bands from {ci} in total\
        <li>{tgb} {ge} bands in total</em><ul></p>",
        sticky=True)

    locations.append([la,lo])
    popups.append(popup)
        
cluster = marker_cluster.MarkerCluster(locations,popups)
        
#         folium.Marker(
#             location=[la,lo],
#             tooltip=f'{ci} ({co}) is the home of: {ge}<br/>with {num} {ge} band(s)',
#             popup=popup,
#             icon=folium.Icon(icon_color='white')
#         ).add_to(m2)

m2.add_child(cluster)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7211941b2c574dd18b6d0a06dcc927d6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7211941b2c574dd18b6d0a06dcc927d6%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...
