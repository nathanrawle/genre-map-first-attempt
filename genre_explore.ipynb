# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from string import punctuation

# %%
pd.set_option('display.max_rows', 100)

# %%
wd = pd.read_csv('./WikiData/musicalgroup_genre.csv',usecols=[1,3], header=0, names=['artist','genre'])

wd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55139 entries, 0 to 55138
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   artist  55139 non-null  object
#  1   genre   55139 non-null  object
# dtypes: object(2)
# memory usage: 861.7+ KB

# %%
ts = pd.read_csv('./trebi/csv/songs.csv',
                 sep=';',
                 usecols=[0,2,4],
                 header=0,
                 names=['songID','artist','genre'])
ts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579878 entries, 0 to 579877
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   songID  579878 non-null  object
#  1   artist  579878 non-null  object
#  2   genre   579878 non-null  object
# dtypes: object(3)
# memory usage: 13.3+ MB

# %%
song_to_artist = dict(ts[['songID','artist']].values)

# %%
tt = pd.read_csv('./trebi/csv/tags.csv', sep=';', usecols=[0,1], names=['songID','genre'])
tt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1979394 entries, 0 to 1979393
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   songID  object
#  1   genre   object
# dtypes: object(2)
# memory usage: 30.2+ MB

# %% [markdown]
# ## combine & tidy

# %%
gg = pd.concat([wd,ts,tt])
gg['genre'] = gg['genre'].str.strip().str.casefold()
gg = gg.drop_duplicates()

# %%
gg.nunique()
# Out:
# artist    193411
# genre       2308
# songID    203844
# dtype: int64

# %%
demonyms = ['anatolian', 'argentine', 'basque',
            'boston', 'brazilian', 'bulgarian', 'catalan',
            'chilean', 'colombian', 'czech', 'dutch',
            'french', 'hungarian', 'indian',
            'kiwi', 'kraut', 'norwegian', 'peruvian', 'portuguese',
            'romanian', 'russian', 'scottish', 'slovenian', 'spanish',
            'suomi', 'swiss', 'swedish', 'turkish', 'ukrainian', 'venezuelan',
            'welsh', 'yugoslav','slovak','estonian','icelandic',
            'indonesian', 'albuquerque', 'canadian', 'la',
            'vancouver', 'australian', 'perth', 'german', 'brooklyn',
            'vienna', 'portland', 'vegas', 'mexican', 'sheffield',
            'ok', 'rva', 'athens', 'belgian',
            'slc', 'finnish', 'chicago', 'polish', 'seattle',
            'leeds', 'nz', 'thai', 'louisville', 'danish',
            'denver', 'michigan', 'stl', 'kc', 'triangle',
            'greek', 'irish', 'bay area', 'thai', 'pakistani',
            'polynesian', 'latvian', 'arab', 'korean', 'brazilian',
            'taiwanese', 'faroese', 'austrian', 'persian', 'chinese',
            'italian', 'american', 'puerto rican', 'detroit', 'louisiana',
            'new orleans', 'uk'
           ]

# %%
for nym in demonyms:
    mask = gg['genre'].str.contains(nym,na=False)
    match = gg.loc[mask,'genre'].str.extract('(.*)('+nym+'[ -])(.*)')
    gg.loc[mask,'genre'] = (match[0]+match[2]).str.strip()

# %%
gg.nunique()
# Out:
# artist    193411
# genre       1835
# songID    203844
# dtype: int64

# %%
mask = gg['genre'].str.contains("music$",na=False)

gg.loc[mask,'genre'] = gg.loc[mask,'genre'].str.extract("(.*)([ -]music$)")[0]

# %%
gg.nunique()
# Out:
# artist    193411
# genre       1777
# songID    203844
# dtype: int64

# %%
hyphens = gg['genre'].str.contains("-", na=False)
nohy = gg.loc[~hyphens,'genre'].values
mask = gg['genre'].str.replace("-"," ").isin(nohy)
gg.loc[hyphens&mask,'genre'] = gg.loc[hyphens&mask,'genre'].str.replace("-"," ")

# %%
gg['genre'] = gg['genre'].str.replace("hip hop", "hip-hop")
gg['genre'] = gg['genre'].str.replace("rock steady", "rocksteady")

# %%
gg.nunique()
# Out:
# artist    193411
# genre       1762
# songID    203844
# dtype: int64

# %%
gg.loc[gg['genre'].str.contains('(?<!deep)[ ]indie$',na=False),'genre'] = 'indie'

gg.loc[gg['genre'].notna()&gg['genre'].str.contains(r'electronic dance'), 'genre'] = 'edm'

gg.loc[gg['genre'].str.contains('[ -]singer[- ]songwriter',na=False),'genre'] = 'singer-songwriter'

# %%
gg.nunique()
# Out:
# artist    193411
# genre       1755
# songID    203844
# dtype: int64

# %%
letters = '[^\s'+punctuation.replace('&','')+']+'
word = letters+'-?'+letters

# %%
tlg_mask = gg['genre'].str.fullmatch(letters+'-?'+letters,na=False)
tlgs = gg.loc[tlg_mask,'genre'].unique()
tlg_counts = gg.loc[tlg_mask,'genre'].value_counts()

# %%
sg1_mask = gg['genre'].str.fullmatch(word+' '+word,na=False)
sg1s = gg.loc[sg1_mask,'genre'].unique()
sg1_counts = gg.loc[sg1_mask,'genre'].value_counts()

# %%
sg2_mask = gg['genre'].str.fullmatch(word+' '+word+' '+word,na=False)
sg2s = gg.loc[sg2_mask,'genre'].unique()
sg2_counts = gg.loc[sg2_mask,'genre'].value_counts()

# %%
tlg_counts
# Out:
# rock          13161
# pop           10533
# indie          9049
# hip-hop        6307
# jazz           3500
#               ...
# percussion        1
# ragamuffin        1
# plena             1
# q4444866          1
# p-pop             1
# Name: genre, Length: 718, dtype: int64

# %%
sg1_counts
# Out:
# alternative rock    4176
# punk rock           3729
# indie rock          3250
# pop rock            2088
# indie pop           1882
#                     ...
# free tekno             1
# cumbia amazónica       1
# ritual ambient         1
# moroccan chaabi        1
# heavy psych            1
# Name: genre, Length: 803, dtype: int64

# %%
sg2_counts
# Out:
# melodic death metal      576
# deep indie pop           493
# rhythm and blues         474
# technical death metal    338
# deep acoustic pop        324
#                         ...
# awa dance festival         1
# canti del maggio           1
# florida death metal        1
# music of morocco           1
# scrumpy and western        1
# Name: genre, Length: 198, dtype: int64

# %%
gg.loc[
    gg['artist'].isna()
    &gg['songID'].isin(song_to_artist.keys()),
    'artist'
] = gg.loc[
    gg['artist'].isna()
    &gg['songID'].isin(song_to_artist.keys()),
    'songID'].replace(song_to_artist)

gg = gg.drop_duplicates(['artist','genre'])

# %%
gg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 299259 entries, 0 to 989697
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   artist  299257 non-null  object
#  1   genre   277549 non-null  object
#  2   songID  244313 non-null  object
# dtypes: object(3)
# memory usage: 9.1+ MB

# %%
wd.loc[wd['artist'].str.contains('Brown')]
# Out:
#                                           artist                    genre
# 459                               Zac Brown Band            country music
# 831              The Crazy World of Arthur Brown         psychedelic rock
# 1241                        Ray, Goodman & Brown         rhythm and blues
# 4267                                Buster Brown                      pop
# 4268                                Buster Brown                hard rock
# 5059                             Blue King Brown                   reggae
# 5948                           Charlie Brown Jr.                   reggae
# 5949                           Charlie Brown Jr.            hardcore punk
# 5950                           Charlie Brown Jr.         alternative rock
# 5951                           Charlie Brown Jr.                      ska
# 5952                           Charlie Brown Jr.                 ska punk
# 5953                           Charlie Brown Jr.                 pop rock
# 5954                           Charlie Brown Jr.                 pop-punk
# 5955                           Charlie Brown Jr.               funk metal
# 5956                           Charlie Brown Jr.               Skate punk
# 5957                           Charlie Brown Jr.                funk rock
# 5958                           Charlie Brown Jr.                rap metal
# 5959                           Charlie Brown Jr.                 rap rock
# 5960                           Charlie Brown Jr.                  rapcore
# 5961                           Charlie Brown Jr.              reggae rock
# 9090                          Brown’s Ferry Four             gospel music
# 10672                                Savoy Brown         psychedelic rock
# 15875                                 The Browns            country music
# 16168                          Brown Indian Band                     jazz
# 16281                              Brown Brigade              heavy metal
# 17922                        Brownsville Station                hard rock
# 20113                           Brownman Revival                   reggae
# 22666                Chris Brown and Kate Fenner                folk rock
# 22728      Clairy Browne & The Bangin’ Rackettes               soul music
# 23250                               Bosque Brown      alternative country
# 23573                     Barbara and the Browns         rhythm and blues
# 23685                                Brown Sauce                pop music
# 23686                           Browning Mummery         electronic music
# 23687                                  Brownside            hip hop music
# 25937                               Family Brown            country music
# 26400                           Flashlight Brown                punk rock
# 27006                                 Lucy Brown                funk rock
# 28557                             Pink and Brown         alternative rock
# 28909                          John Brown's Body                   reggae
# 29212                          Miss Willie Brown            country music
# 29425                             Prescott-Brown            country music
# 30313                               Sawyer Brown            country music
# 30392                           Small Brown Bike                punk rock
# 31165                               The 5 Browns  Western classical music
# 31859                   The Danny Joe Brown Band            Southern rock
# 32188                               The Browning                deathcore
# 32208                         Six Brown Brothers                     jazz
# 32209                         Six Brown Brothers               vaudeville
# 35679                                      Brown               rock music
# 41828  Kid Rock & The Twisted Brown Trucker Band              heavy metal
# 41926                                 Brown Bird               folk music
# 42835      John Cafferty & The Beaver Brown Band               rock music
# 46584                               Future Brown         electronic music
# 47089                         Brown Bag AllStars                  rapping
# 47090                         Brown Bag AllStars            hip hop music
# 47091                         Brown Bag AllStars       instrumental music
# 52849               Sonny Terry & Brownie McGhee                    blues
# 54638         Chuck Brown and the Soul Searchers                    go-go
# 54884                            Сhameleon Brown               electropop

# %%
gc = gg.melt(['genre'],
             value_name='song/artist'
            ).drop('variable',
                   axis=1
                  ).value_counts('genre'
                                ).reset_index().rename(columns={0:'count'})

gc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1755 entries, 0 to 1754
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   genre   1755 non-null   object
#  1   count   1755 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 27.5+ KB

# %%
gc.head(100)
# Out:
#                   genre  count
# 0                  rock  22606
# 1                   pop  17356
# 2                 indie  14796
# 3               hip-hop  11434
# 4      alternative rock   7834
# 5             punk rock   7458
# 6                  jazz   6370
# 7            indie rock   6014
# 8                  folk   5352
# 9                  punk   4180
# 10             pop rock   3642
# 11                j-pop   3514
# 12            indie pop   3136
# 13               reggae   3126
# 14            hard rock   3108
# 15     progressive rock   2906
# 16                metal   2596
# 17              country   2542
# 18        hardcore punk   2366
# 19         thrash metal   2328
# 20          death metal   2276
# 21          heavy metal   2126
# 22             deep pop   2000
# 23             new wave   1936
# 24                house   1736
# 25    progressive metal   1608
# 26           electronic   1452
# 27    singer-songwriter   1446
# 28    contemporary folk   1406
# 29               gospel   1380
# 30               techno   1308
# 31            folk rock   1300
# 32             pop punk   1266
# 33             folk pop   1246
# 34                blues   1232
# 35          traditional   1220
# 36     psychedelic rock   1210
# 37                  ccm   1200
# 38         deep hip-hop   1200
# 39           deep indie   1122
# 40          garage rock   1094
# 41            eurodance   1064
# 42            post rock   1034
# 43            post-punk   1024
# 44            metalcore   1014
# 45          power metal   1006
# 46            synth-pop    996
# 47                 soul    972
# 48  melodic death metal    964
# 49                disco    964
# 50     rhythm and blues    948
# 51            dance pop    936
# 52          gothic rock    934
# 53           doom metal    924
# 54          electronica    904
# 55                 funk    898
# 56                  ska    892
# 57                  dub    882
# 58          street punk    852
# 59    alternative metal    836
# 60            noise pop    834
# 61        post-hardcore    828
# 62         indietronica    824
# 63             hardcore    804
# 64             art rock    800
# 65           show tunes    800
# 66        rock-and-roll    800
# 67     traditional folk    800
# 68       deep indie pop    800
# 69                 idol    800
# 70                opera    798
# 71             synthpop    788
# 72           blues rock    784
# 73          speed metal    778
# 74          stoner rock    774
# 75            power pop    760
# 76                   oi    754
# 77          alternative    752
# 78  alternative country    748
# 79                world    744
# 80            bluegrass    730
# 81    experimental rock    712
# 82         gothic metal    702
# 83             dansband    702
# 84              electro    692
# 85            grindcore    688
# 86              doo-wop    682
# 87             nu metal    676
# 88           noise rock    662
# 89       christian rock    660
# 90          movie tunes    658
# 91           industrial    658
# 92          jazz fusion    658
# 93         experimental    654
# 94      symphonic metal    648
# 95     industrial metal    648
# 96             trip hop    646
# 97                  emo    634
# 98             ska punk    630
# 99           indie folk    622
